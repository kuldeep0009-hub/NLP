# %% [markdown]
# <a href="https://colab.research.google.com/github/kuldeep0009-hub/NLP/blob/main/kindle_review_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/all_kindle_review .csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        asin  helpful  rating  \
# 0             0       11539  B0033UV8HI  [8, 10]       3
# 1             1        5957  B002HJV4DE   [1, 1]       5
# 2             2        9146  B002ZG96I4   [0, 0]       3
# 3             3        7038  B002QHWOEU   [1, 3]       3
# 4             4        1776  B001A06VJ8   [0, 1]       4
#
#                                           reviewText   reviewTime  \
# 0  Jace Rankin may be short, but he's nothing to ...   09 2, 2010
# 1  Great short read.  I didn't want to put it dow...   10 8, 2013
# 2  I'll start by saying this is the first of four...  04 11, 2014
# 3  Aggie is Angela Lansbury who carries pocketboo...   07 5, 2014
# 4  I did not expect this type of book to be in li...  12 31, 2012
#
#        reviewerID  reviewerName                   summary  unixReviewTime
# 0  A3HHXRELK8BHQG        Ridley  Entertaining But Average      1283385600
# 1  A2RGNZ0TRF578I  Holly Butler   Terrific menage scenes!      1381190400
# ...

# %%
df.isnull().sum()
#dataset website jmcauley.ucsd.edu
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# asin               0
# helpful            0
# rating             0
# reviewText         0
# reviewTime         0
# reviewerID         0
# reviewerName      38
# summary            2
# unixReviewTime     0
# dtype: int64

# %%
df.shape
# Out:
# (12000, 11)

# %%
#preprocessing and cleaning
df=df[['reviewText','rating']]

# %%
df.head()
# Out:
#                                           reviewText  rating
# 0  Jace Rankin may be short, but he's nothing to ...       3
# 1  Great short read.  I didn't want to put it dow...       5
# 2  I'll start by saying this is the first of four...       3
# 3  Aggie is Angela Lansbury who carries pocketboo...       3
# 4  I did not expect this type of book to be in li...       4

# %%
df.shape
# Out:
# (12000, 2)

# %%
df.isnull().sum()
# Out:
# reviewText    0
# rating        0
# dtype: int64

# %%
df['rating'].unique()
# Out:
# array([3, 5, 4, 2, 1])

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    3000
# 4    3000
# 3    2000
# 2    2000
# 1    2000
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                           reviewText  rating
# 0  Jace Rankin may be short, but he's nothing to ...       3
# 1  Great short read.  I didn't want to put it dow...       5
# 2  I'll start by saying this is the first of four...       3
# 3  Aggie is Angela Lansbury who carries pocketboo...       3
# 4  I did not expect this type of book to be in li...       4

# %%
df['rating']=df['rating'].apply (lambda x:0 if x<3 else 1)

# %%
df.head(50)
# Out:
#                                            reviewText  rating
# 0   Jace Rankin may be short, but he's nothing to ...       1
# 1   Great short read.  I didn't want to put it dow...       1
# 2   I'll start by saying this is the first of four...       1
# 3   Aggie is Angela Lansbury who carries pocketboo...       1
# 4   I did not expect this type of book to be in li...       1
# 5   Aislinn is a little girl with big dreams. Afte...       1
# 6   This has the makings of a good story... unfort...       0
# 7   I got this because I like collaborated short s...       1
# 8   Loved this book, I am hooked on this series an...       1
# 9   And that's a good thing. Short, sweet tease th...       1
# 10  I received a copy of book to review. "A secret...       0
# 11  Even though you already know what the outcome ...       1
# 12  I read the other reviews and decided to give i...       0
# 13  I just finished a re-read of WICKED GARDEN and...       1
# ...

# %%
df['rating'].unique()
# Out:
# array([1, 0])

# %%
 df['rating'].value_counts()
# Out:
# rating
# 1    8000
# 0    4000
# Name: count, dtype: int64

# %%
## lower all the ccases
df['reviewText']=df['reviewText'].str.lower()
import re
import nltk
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
## removing special characters
df['reviewText']=df['reviewText'].apply(lambda x:re.sub('[^a-z A-Z 0-9]+','',x))
# remove the stopwords
df['reviewText']=df['reviewText'].apply(lambda x:" ".join([y for y in x.split() if y not in stopwords.words('english')]))


#remove url
df['reviewText'] = df['reviewText'].apply(lambda x: re.sub(r'(http|https|ftp|ssh)://\S+', '', str(x)))

#remove html tag
df['reviewText']=df['reviewText'].apply(lambda x: BeautifulSoup(x,'lxml').get_text())
#remove additional space
df['reviewText']=df['reviewText'].apply(lambda x: ' '.join (x.split()))

# %%
 ## lemmatizer
 from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
def lemmatize_word(text):
  return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df['reviewText']=df['reviewText'].apply(lambda x:lemmatize_word(x))

# %%
## train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df['reviewText'],df['rating'],test_size=0.20)

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow=CountVectorizer()
x_train_bow=bow.fit_transform(x_train).toarray()
x_test_bow=bow.transform(x_test).toarray()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
x_train_tfidf=tfidf.fit_transform(x_train).toarray()
x_test_tfidf=tfidf.transform(x_test).toarray()

# %%
from sklearn.naive_bayes import GaussianNB
nb_model=GaussianNB().fit(x_train_bow,y_train)
nb_model=GaussianNB().fit(x_train_tfidf,y_train)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
y_pred_bow=nb_model.predict(x_test_bow)

# %%
y_pred_tfidf=nb_model.predict(x_test_tfidf)

# %%
print(accuracy_score(y_test,y_pred_bow)," : BOW accuracy")
# Out:
# 0.59625  : BOW accuracy
